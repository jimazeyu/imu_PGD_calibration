# %% [markdown]
# # Load Data

# %%
import pickle
import sys
import time 
import numpy as np
import transforms3d as tf3d

def tic():
  return time.time()
def toc(tstart, nm=""):
  print('%s took: %s sec.\n' % (nm,(time.time() - tstart)))

def read_data(fname):
  d = []
  with open(fname, 'rb') as f:
    if sys.version_info[0] < 3:
      d = pickle.load(f)
    else:
      d = pickle.load(f, encoding='latin1')  # needed for python 3
  return d

dataset="10"
cfile = "./data/testset/cam/cam" + dataset + ".p"
ifile = "./data/testset/imu/imuRaw" + dataset + ".p"
ts = tic()
# camd = read_data(cfile)
imud = read_data(ifile)
toc(ts,"Data import")
# Out:
# Data import took: 0.0005931854248046875 sec.

# %% [markdown]
# # IMU Calibration

# %%
imud_vals = imud['vals'].transpose().reshape(-1,6)
# change imud_vals to int16
imud_vals = imud_vals.astype('int16')
imud_ts = imud['ts'].reshape(-1,1)
initial_time = imud_ts[0]
imud_ts = imud_ts - initial_time
print("imu vals shape: ", imud_vals.shape)
print("imu ts shape: ", imud_ts.shape)
# Out:
# imu vals shape:  (3078, 6)
# imu ts shape:  (3078, 1)

# %%
imud_vals[0]
# Out:
# array([511, 501, 606, 369, 375, 376], dtype=int16)

# %%
def read_imu_data(imu_data):
    # Splitting the matrix into acceleration and angular rate components
    acceleration = imu_data[:, :3]
    angular_rate = imu_data[:, [4, 5, 3]]  # Reordering to Wx, Wy, Wz
    # Correcting the sign due to device design flip
    acceleration[:, 0] = acceleration[:, 0]
    acceleration[:, 1] = acceleration[:, 1]
    acceleration[:, 2] = -acceleration[:, 2]
    return acceleration, angular_rate

# %%
# Plotting the raw data to calculate the bias
import matplotlib.pyplot as plt

acc_raw, gyro_raw = read_imu_data(imud_vals)
# Plot each axis of the accelerometer
acc_X = acc_raw[:, 0]
acc_Y = acc_raw[:, 1]
acc_Z = acc_raw[:, 2]
# Plot each axis of the accelerometer
plt.subplot(3, 1, 1)
plt.plot(imud_ts, acc_X)
plt.ylabel('X')
plt.title('Accelerometer Raw Data')
plt.subplot(3, 1, 2)
plt.plot(imud_ts, acc_Y)
plt.ylabel('Y')
plt.subplot(3, 1, 3)
plt.plot(imud_ts, acc_Z)
plt.ylabel('Z')
plt.xlabel('Time (sec)')
plt.show()

# Plot each axis of the gyroscope
gyro_X = gyro_raw[:, 0]
gyro_Y = gyro_raw[:, 1]
gyro_Z = gyro_raw[:, 2]
plt.subplot(3, 1, 1)
plt.plot(imud_ts, gyro_X)
plt.ylabel('X')
plt.title('Gyroscope Raw Data')
plt.subplot(3, 1, 2)
plt.plot(imud_ts, gyro_Y)
plt.ylabel('Y')
plt.subplot(3, 1, 3)
plt.plot(imud_ts, gyro_Z)
plt.ylabel('Z')
plt.xlabel('Time (sec)')
plt.show()

# %%
def convert_raw_to_physical(raw, sensitivity, Vref=3300, bias=0, is_gyro=False):
    scale_factor = Vref / 1023 / sensitivity
    if is_gyro:
        # Convert to radians/sec for gyro
        physical_values = (raw - bias) * scale_factor * np.pi / 180
    else:
        # Convert to g for accelerometer
        physical_values = (raw - bias) * scale_factor

    return physical_values

# %%
# Use first 100 samples of X to calculate the bias
acc_bias_X = np.mean(acc_X[:100]) # 0.0
acc_bias_Y = np.mean(acc_Y[:100]) # 0.0
scale_factor = 3300 / 1023 / 300
acc_bias_Z = np.mean(acc_Z[:100]) + 1.0 / scale_factor
gyro_bias_X = np.mean(gyro_X[:100]) # 0.0
gyro_bias_Y = np.mean(gyro_Y[:100]) # 0.0
gyro_bias_Z = np.mean(gyro_Z[:100]) # 0.0
print('Accelerometer bias (g):')
print('X: ', acc_bias_X)
print('Y: ', acc_bias_Y)
print('Z: ', acc_bias_Z)
print('Gyroscope bias (deg/sec):')
print('X: ', gyro_bias_X)
print('Y: ', gyro_bias_Y)
print('Z: ', gyro_bias_Z)
# Out:
# Accelerometer bias (g):
# X:  511.04
# Y:  501.0
# Z:  -513.01
# Gyroscope bias (deg/sec):
# X:  373.51
# Y:  375.41
# Z:  369.65

# %%
# Converting the raw IMU data to physical values
acc = np.zeros((len(imud_ts), 3))
gyro = np.zeros((len(imud_ts), 3))
acc[:,0] = convert_raw_to_physical(acc_X, 300, Vref=3300, bias=acc_bias_X)
acc[:,1] = convert_raw_to_physical(acc_Y, 300, Vref=3300, bias=acc_bias_Y)
acc[:,2] = convert_raw_to_physical(acc_Z, 300, Vref=3300, bias=acc_bias_Z)
gyro[:,0] = convert_raw_to_physical(gyro_X, 3.33, Vref=3300, bias=gyro_bias_X, is_gyro=True)
gyro[:,1] = convert_raw_to_physical(gyro_Y, 3.33, Vref=3300, bias=gyro_bias_Y, is_gyro=True)
gyro[:,2] = convert_raw_to_physical(gyro_Z, 3.33, Vref=3300, bias=gyro_bias_Z, is_gyro=True)

# %%
# Plotting the physical data
# Plot each axis of the accelerometer
acc_X = acc[:, 0]
acc_Y = acc[:, 1]
acc_Z = acc[:, 2]
plt.subplot(3, 1, 1)
plt.plot(imud_ts, acc_X)
plt.ylabel('X(g)')
plt.title('Accelerometer Physical Data')
plt.subplot(3, 1, 2)
plt.plot(imud_ts, acc_Y)
plt.ylabel('Y(g)')
plt.subplot(3, 1, 3)
plt.plot(imud_ts, acc_Z)
plt.ylabel('Z(g)')
plt.xlabel('Time (sec)')
plt.show()

# Plot each axis of the gyroscope
gyro_X = gyro[:, 0]
gyro_Y = gyro[:, 1]
gyro_Z = gyro[:, 2]
plt.subplot(3, 1, 1)
plt.plot(imud_ts, gyro_X)
plt.ylabel('X(rad/sec)')
plt.title('Gyroscope Physical Data')
plt.subplot(3, 1, 2)
plt.plot(imud_ts, gyro_Y)
plt.ylabel('Y(rad/sec)')
plt.subplot(3, 1, 3)
plt.plot(imud_ts, gyro_Z)
plt.ylabel('Z(rad/sec)')
plt.xlabel('Time (sec)')
plt.show()

# %% [markdown]
# # Optimization

# %%
q_imu = tf3d.quaternions.np.array([1, 0, 0, 0])
q_imu_list = []
for i in range(len(imud_ts)):
    if i == 0:
        q_imu_list.append(q_imu)
        continue
    else:
        time_elapsed = (imud_ts[i] - imud_ts[i-1])[0]
        q_omega_tau = tf3d.quaternions.np.array([0, gyro[i-1, 0] * time_elapsed / 2, gyro[i-1, 1] * time_elapsed / 2, gyro[i-1, 2] * time_elapsed / 2])
        q_imu = tf3d.quaternions.qmult(q_imu, tf3d.quaternions.qexp(q_omega_tau))
        q_imu_list.append(q_imu)
        
imu_yaw = np.zeros(len(imud_ts))
imu_pitch = np.zeros(len(imud_ts))
imu_roll = np.zeros(len(imud_ts))
for i in range(len(imud_ts)):
    imu_yaw[i], imu_pitch[i], imu_roll[i] = tf3d.euler.quat2euler(q_imu_list[i], axes='sxyz')

# %%
import jax.numpy as jnp

def qexp_batched(q):
    qs, qv = q[..., 0], q[..., 1:]
    norm_qv = jnp.linalg.norm(qv, axis=-1, keepdims=True)
    scalar = jnp.exp(qs)
    vec = jnp.where(norm_qv > 0, (qv / norm_qv) * jnp.sin(norm_qv), qv)
    return jnp.concatenate([scalar[..., None] * jnp.cos(norm_qv), scalar[..., None] * vec], axis=-1)

def qlog_batched(q):
    qs, qv = q[..., 0], q[..., 1:]
    norm_q = jnp.linalg.norm(q, axis=-1)
    norm_qv = jnp.linalg.norm(qv, axis=-1)
    cos_term = jnp.clip(qs / norm_q, -1, 1)
    vec = jnp.where(
        norm_qv[..., None] > 0,
        (qv / norm_qv[..., None]) * jnp.arccos(cos_term)[..., None],
        qv
    )
    return jnp.concatenate([jnp.log(norm_q)[..., None], vec], axis=-1)

def qinverse_batched(q):
    w, x, y, z = q[..., 0], q[..., 1], q[..., 2], q[..., 3]
    norm_squared = jnp.sum(q * q, axis=-1, keepdims=True)
    return jnp.stack([w, -x, -y, -z], axis=-1) / norm_squared

def qmult_batched(q1, q2):
    w1, x1, y1, z1 = q1[..., 0], q1[..., 1], q1[..., 2], q1[..., 3]
    w2, x2, y2, z2 = q2[..., 0], q2[..., 1], q2[..., 2], q2[..., 3]

    w = w1 * w2 - x1 * x2 - y1 * y2 - z1 * z2
    x = w1 * x2 + x1 * w2 + y1 * z2 - z1 * y2
    y = w1 * y2 - x1 * z2 + y1 * w2 + z1 * x2
    z = w1 * z2 + x1 * y2 - y1 * x2 + z1 * w2

    return jnp.stack([w, x, y, z], axis=-1)
# loss function
def loss_function(q_imu, acc):
    global imud_ts, gyro
    # Batched version of the motion error
    motion_error = 0
    q1 = q_imu[:-1]
    q2 = q_imu[1:]
    time_elapsed = (imud_ts[1:] - imud_ts[:-1])[:, 0]
    q_omega_tau = jnp.stack([jnp.zeros_like(time_elapsed), gyro[:-1, 0] * time_elapsed / 2, gyro[:-1, 1] * time_elapsed / 2, gyro[:-1, 2] * time_elapsed / 2], axis=-1)
    q2 = qmult_batched(q2, qexp_batched(q_omega_tau))
    q1_inv_q2 = qmult_batched(qinverse_batched(q1), q2)
    q1_inv_q2 = jnp.round(q1_inv_q2, 8)
    motion_error = jnp.sum(jnp.linalg.norm(2 * qlog_batched(q1_inv_q2), axis=-1)**2)
    
    # # Batched version of the observation error
    observation_error = 0
    q = q_imu[1:]
    a = acc[1:]
    g = jnp.array([0, 0, 0, -1.0])
    # observation = qmult_batched(qinverse_batched(q), qmult_batched(g, q))
    observation = qmult_batched(qinverse_batched(q), qmult_batched(g, q))
    observation_error = jnp.sum(jnp.linalg.norm(a - observation[..., 1:], axis=-1)**2)

    print("motion_error: ", motion_error)
    print("observation_error: ", observation_error)
    return 0.5 * motion_error + 0.5 * observation_error

# loss function
def part_loss_function(q_imu, acc):
    global imud_ts, gyro
    # Batched version of the motion error
    motion_error = 0
    q1 = q_imu[:-1]
    q2 = q_imu[1:]
    time_elapsed = (imud_ts[1:] - imud_ts[:-1])[:, 0]
    q_omega_tau = jnp.stack([jnp.zeros_like(time_elapsed), gyro[:-1, 0] * time_elapsed / 2, gyro[:-1, 1] * time_elapsed / 2, gyro[:-1, 2] * time_elapsed / 2], axis=-1)
    q2 = qmult_batched(q2, qexp_batched(q_omega_tau))
    q1_inv_q2 = qmult_batched(qinverse_batched(q1), q2)
    q1_inv_q2 = jnp.round(q1_inv_q2, 8)
    motion_error = jnp.sum(jnp.linalg.norm(2 * qlog_batched(q1_inv_q2), axis=-1)**2)
    
    # # Batched version of the observation error
    observation_error = 0
    q = q_imu[1:]
    a = acc[1:]
    g = jnp.array([0, 0, 0, -1.0])
    # observation = qmult_batched(qinverse_batched(q), qmult_batched(g, q))
    observation = qmult_batched(qinverse_batched(q), qmult_batched(g, q))
    observation_error = jnp.sum(jnp.linalg.norm(a - observation[..., 1:], axis=-1)**2)

    return 0.5 * motion_error, 0.5 * observation_error

# %%
from jax import jit, grad, vmap
import jax.numpy as jnp

# Gradient computation
grad_loss = jit(grad(loss_function))

# Helper function to project gradient onto tangent plane of the sphere
def project_onto_tangent_plane(gradient, q_imu):
    # Project the gradient onto the tangent plane at q_imu
    return gradient - q_imu * jnp.dot(q_imu, gradient)

# Optimization process
def optimize_quaternions(q_imu, acc, learning_rate=0.01, num_iterations=100):
    loss_list = []
    for i in range(num_iterations):
        # Compute the gradient
        gradients = grad_loss(q_imu, acc)
        
        # Project the gradient onto the tangent plane of the sphere at q_imu
        tangent_gradients = vmap(project_onto_tangent_plane)(gradients, q_imu)
        
        # Update quaternion parameters with a simple learning rate
        q_imu = q_imu - learning_rate * tangent_gradients
        
        # Renormalize the quaternion to ensure it stays on the unit sphere
        q_imu = q_imu / jnp.linalg.norm(q_imu, axis=1, keepdims=True)
        
        loss = loss_function(q_imu, acc)

        motion_error, observation_error = part_loss_function(q_imu, acc)

        loss_list.append((motion_error, observation_error))

        print('Iteration', i, 'Loss', loss)
    
    return q_imu, loss_list


q_imu_np = np.array(q_imu_list)
acc_np = np.array(acc)
optimized_quaternions, loss_list = optimize_quaternions(q_imu_np, acc_np)
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# motion_error:  Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=1/0)>
# observation_error:  Traced<ShapedArray(float32[])>with<JVPTrace(level=3/0)> with
#   primal = Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=1/0)>
#   tangent = Traced<ShapedArray(float32[])>with<JaxprTrace(level=2/0)> with
#     pval = (ShapedArray(float32[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7fe7809e31d0>, in_tracers=(Traced<ShapedArray(float32[3077]):JaxprTrace(level=2/0)>,), out_tracer_refs=[<weakref at 0x7fe7809eba40; to 'JaxprTracer' at 0x7fe7809ebae0>], out_avals=[ShapedArray(float32[])], primitive=pjit, params={'jaxpr': { lambda ; a:f32[3077]. let b:f32[] = reduce_sum[axes=(0,)] a in (b,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'resource_env': None, 'donated_invars': (False,), 'name': '_reduce_sum', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x7fe7809efcf0>, name_stack=NameStack(stack=(Transform(name='jvp'),))))
# motion_error:  0.23916084
# observation_error:  99.19915
# Iteration 0 Loss 49.719154
# motion_error:  0.24703115
# observation_error:  93.83847
# Iteration 1 Loss 47.04275
# motion_error:  0.25944012
# observation_error:  88.87013
# Iteration 2 Loss 44.564785
# motion_error:  0.27549052
# observation_error:  84.26703
# Iteration 3 Loss 42.27126
# motion_error:  0.29456484
# observation_error:  80.0038
# Iteration 4 Loss 40.14918
# motion_error:  0.31606042
# observation_error:  76.05662
# Iteration 5 Loss 38.18634
# motion_error:  0.33962494
# observation_error:  72.403244
# Iteration 6 Loss 36.371433
# motion_error:  0.3647182
# observation_error:  69.02281
# Iteration 7 Loss 34.693764
# motion_error:  0.39117894
# observation_error:  65.89583
# Iteration 8 Loss 33.143505
# motion_error:  0.4186077
# observation_error:  63.004066
# Iteration 9 Loss 31.711338
# motion_error:  0.44686517
# observation_error:  60.330498
# Iteration 10 Loss 30.388681
# motion_error:  0.47565907
# observation_error:  57.859238
# Iteration 11 Loss 29.167448
# motion_error:  0.5048387
# observation_error:  55.57548
# Iteration 12 Loss 28.04016
# motion_error:  0.5342625
# observation_error:  53.46542
# Iteration 13 Loss 26.999842
# motion_error:  0.5638139
# observation_error:  51.516224
# Iteration 14 Loss 26.040018
# motion_error:  0.5933201
# observation_error:  49.71592
# Iteration 15 Loss 25.15462
# motion_error:  0.62273306
# observation_error:  48.053425
# Iteration 16 Loss 24.33808
# motion_error:  0.6519489
# observation_error:  46.518394
# Iteration 17 Loss 23.58517
# motion_error:  0.6809067
# observation_error:  45.10126
# Iteration 18 Loss 22.891085
# motion_error:  0.7095191
# observation_error:  43.793133
# Iteration 19 Loss 22.251326
# motion_error:  0.7377064
# observation_error:  42.58575
# Iteration 20 Loss 21.661728
# motion_error:  0.7655019
# observation_error:  41.471485
# Iteration 21 Loss 21.118494
# motion_error:  0.79282176
# observation_error:  40.443253
# Iteration 22 Loss 20.618036
# motion_error:  0.8196354
# observation_error:  39.494484
# Iteration 23 Loss 20.157059
# motion_error:  0.84592175
# observation_error:  38.619118
# Iteration 24 Loss 19.73252
# motion_error:  0.8716041
# observation_error:  37.811535
# Iteration 25 Loss 19.34157
# motion_error:  0.89676017
# observation_error:  37.06652
# Iteration 26 Loss 18.98164
# motion_error:  0.9213126
# observation_error:  36.379288
# Iteration 27 Loss 18.650301
# motion_error:  0.94526803
# observation_error:  35.74537
# Iteration 28 Loss 18.345318
# motion_error:  0.9686719
# observation_error:  35.16067
# Iteration 29 Loss 18.064672
# motion_error:  0.991432
# observation_error:  34.62139
# Iteration 30 Loss 17.806412
# motion_error:  1.013628
# observation_error:  34.12402
# Iteration 31 Loss 17.568825
# motion_error:  1.0351856
# observation_error:  33.665318
# Iteration 32 Loss 17.350252
# motion_error:  1.0561712
# observation_error:  33.24229
# Iteration 33 Loss 17.149231
# motion_error:  1.076582
# observation_error:  32.85217
# Iteration 34 Loss 16.964375
# motion_error:  1.096365
# observation_error:  32.49241
# Iteration 35 Loss 16.794388
# motion_error:  1.1155921
# observation_error:  32.16065
# Iteration 36 Loss 16.63812
# motion_error:  1.1342793
# observation_error:  31.854721
# Iteration 37 Loss 16.4945
# motion_error:  1.1523842
# observation_error:  31.57261
# Iteration 38 Loss 16.362497
# motion_error:  1.169942
# observation_error:  31.31247
# Iteration 39 Loss 16.241205
# motion_error:  1.1869795
# observation_error:  31.07259
# Iteration 40 Loss 16.129786
# motion_error:  1.2034631
# observation_error:  30.85139
# Iteration 41 Loss 16.027428
# motion_error:  1.2194561
# observation_error:  30.647425
# Iteration 42 Loss 15.93344
# motion_error:  1.2349368
# observation_error:  30.459347
# Iteration 43 Loss 15.847142
# motion_error:  1.2499522
# observation_error:  30.285917
# Iteration 44 Loss 15.767935
# motion_error:  1.2644733
# observation_error:  30.125998
# Iteration 45 Loss 15.695235
# motion_error:  1.2785558
# observation_error:  29.978535
# Iteration 46 Loss 15.628545
# motion_error:  1.2921474
# observation_error:  29.842554
# Iteration 47 Loss 15.56735
# motion_error:  1.3053116
# observation_error:  29.717165
# Iteration 48 Loss 15.511238
# motion_error:  1.3180655
# observation_error:  29.601538
# Iteration 49 Loss 15.459802
# motion_error:  1.3303903
# observation_error:  29.494915
# Iteration 50 Loss 15.412653
# motion_error:  1.3423058
# observation_error:  29.396591
# Iteration 51 Loss 15.369449
# motion_error:  1.3538283
# observation_error:  29.305923
# Iteration 52 Loss 15.329876
# motion_error:  1.3649995
# observation_error:  29.222313
# Iteration 53 Loss 15.293656
# motion_error:  1.3757802
# observation_error:  29.145206
# Iteration 54 Loss 15.260493
# motion_error:  1.386216
# observation_error:  29.074097
# Iteration 55 Loss 15.230156
# motion_error:  1.3962959
# observation_error:  29.008518
# Iteration 56 Loss 15.202407
# motion_error:  1.4060348
# observation_error:  28.948046
# Iteration 57 Loss 15.17704
# motion_error:  1.4154758
# observation_error:  28.892263
# Iteration 58 Loss 15.15387
# motion_error:  1.4245679
# observation_error:  28.840828
# Iteration 59 Loss 15.132698
# motion_error:  1.4333937
# observation_error:  28.79338
# Iteration 60 Loss 15.113387
# motion_error:  1.4418886
# observation_error:  28.749622
# Iteration 61 Loss 15.095756
# motion_error:  1.4501306
# observation_error:  28.709263
# Iteration 62 Loss 15.079697
# motion_error:  1.4580848
# observation_error:  28.672035
# Iteration 63 Loss 15.06506
# motion_error:  1.4657646
# observation_error:  28.637695
# Iteration 64 Loss 15.05173
# motion_error:  1.4731989
# observation_error:  28.60602
# Iteration 65 Loss 15.03961
# motion_error:  1.4804028
# observation_error:  28.576805
# Iteration 66 Loss 15.028604
# motion_error:  1.4873179
# observation_error:  28.54985
# Iteration 67 Loss 15.018584
# motion_error:  1.4940394
# observation_error:  28.524986
# Iteration 68 Loss 15.009513
# motion_error:  1.500543
# observation_error:  28.502048
# Iteration 69 Loss 15.001296
# motion_error:  1.506804
# observation_error:  28.480885
# Iteration 70 Loss 14.993844
# motion_error:  1.5128486
# observation_error:  28.46136
# Iteration 71 Loss 14.987104
# motion_error:  1.5187557
# observation_error:  28.443348
# Iteration 72 Loss 14.981051
# motion_error:  1.5244099
# observation_error:  28.426723
# Iteration 73 Loss 14.975567
# motion_error:  1.5298625
# observation_error:  28.411388
# Iteration 74 Loss 14.970626
# motion_error:  1.5351913
# observation_error:  28.397234
# Iteration 75 Loss 14.966212
# motion_error:  1.5403028
# observation_error:  28.384174
# Iteration 76 Loss 14.962238
# motion_error:  1.5452538
# observation_error:  28.37212
# Iteration 77 Loss 14.958687
# motion_error:  1.550043
# observation_error:  28.361
# Iteration 78 Loss 14.955522
# motion_error:  1.5546836
# observation_error:  28.350729
# Iteration 79 Loss 14.952706
# motion_error:  1.5591598
# observation_error:  28.341259
# Iteration 80 Loss 14.95021
# motion_error:  1.5634905
# observation_error:  28.332508
# Iteration 81 Loss 14.947999
# motion_error:  1.5676725
# observation_error:  28.324434
# Iteration 82 Loss 14.9460535
# motion_error:  1.5717291
# observation_error:  28.31698
# Iteration 83 Loss 14.944355
# motion_error:  1.5756432
# observation_error:  28.3101
# Iteration 84 Loss 14.942872
# motion_error:  1.5794435
# observation_error:  28.303745
# Iteration 85 Loss 14.941594
# motion_error:  1.5831311
# observation_error:  28.297884
# Iteration 86 Loss 14.940508
# motion_error:  1.5866814
# observation_error:  28.292461
# Iteration 87 Loss 14.939571
# motion_error:  1.5901189
# observation_error:  28.287462
# Iteration 88 Loss 14.93879
# motion_error:  1.593429
# observation_error:  28.28284
# Iteration 89 Loss 14.938135
# motion_error:  1.5966538
# observation_error:  28.278572
# Iteration 90 Loss 14.937613
# motion_error:  1.5997655
# observation_error:  28.274633
# Iteration 91 Loss 14.9372
# motion_error:  1.6027914
# observation_error:  28.270992
# Iteration 92 Loss 14.936892
# motion_error:  1.6057031
# observation_error:  28.26763
# Iteration 93 Loss 14.9366665
# motion_error:  1.6085529
# observation_error:  28.26452
# Iteration 94 Loss 14.936537
# motion_error:  1.6112882
# observation_error:  28.261648
# Iteration 95 Loss 14.936468
# motion_error:  1.6139147
# observation_error:  28.258995
# Iteration 96 Loss 14.936455
# motion_error:  1.6165025
# observation_error:  28.25654
# Iteration 97 Loss 14.936522
# motion_error:  1.6189824
# observation_error:  28.254276
# Iteration 98 Loss 14.936629
# motion_error:  1.6213903
# observation_error:  28.252182
# Iteration 99 Loss 14.936787

# %%
# plot 
loss_list = np.array(loss_list)
plt.plot(loss_list[:,0], label='motion error')
plt.plot(loss_list[:,1], label='observation error')
plt.plot(loss_list[:,0] + loss_list[:,1], label='total error')
plt.legend()
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Loss over Iterations')
plt.show()

# %%
# plot optimized imu pose
imu_yaw = np.zeros(len(imud_ts))
imu_pitch = np.zeros(len(imud_ts))
imu_roll = np.zeros(len(imud_ts))
for i in range(len(imud_ts)):
    imu_yaw[i], imu_pitch[i], imu_roll[i] = tf3d.euler.quat2euler(optimized_quaternions[i], axes='sxyz')

plt.subplot(3, 1, 1)
plt.plot(imud_ts, imu_yaw/np.pi*180, label='imu')
plt.ylabel('yaw (deg)')
plt.title('Rotation Estimation')
plt.legend()
plt.subplot(3, 1, 2)
plt.plot(imud_ts, imu_pitch/np.pi*180, label='imu')
plt.ylabel('pitch (deg)')
plt.legend()
plt.subplot(3, 1, 3)
plt.plot(imud_ts, imu_roll/np.pi*180, label='imu')
plt.ylabel('roll (deg)')
plt.legend()
plt.xlabel('Time (sec)')
plt.show()

# %% [markdown]
# # Panorama(Estimated)

# %%
camd = read_data(cfile)
image_list = []
for i in range(0, camd['cam'].shape[3]):
  image_list.append(camd['cam'][:,:,:,i])
print("image_list length: ", len(image_list))
print('image size: ', image_list[0].shape)
# Out:
# image_list length:  911
# image size:  (240, 320, 3)

# %%
# Use the Vicon data to stitch the images together
camd_ts = camd['ts'].reshape(-1,1)
camd_ts = camd_ts - initial_time
def find_closest_timestamps(camera_ts, imu_ts):
    indices = []
    for ts in camera_ts:
        # Compute absolute difference
        diff = np.abs(imu_ts - ts)
        # Find index of the minimum difference
        index = np.argmin(diff)
        indices.append(index)
    return indices

imud_rot_list = []
for i in range(len(imud_ts)):
    R = tf3d.quaternions.quat2mat(optimized_quaternions[i, :])
    imud_rot_list.append(R)
imud_rot_list = np.array(imud_rot_list)
closest_indices = find_closest_timestamps(camd_ts, imud_ts)
closest_orientations = imud_rot_list[closest_indices]

# %%
from scipy.spatial.transform import Rotation as R

def image_to_world_coordinates(image, fov, rotation_matrix):
    h_fov, v_fov = np.radians(fov)  # Convert FOV from degrees to radians
    image_height, image_width = image.shape[:2]

    # Generate grid of pixel coordinates
    x_idx, y_idx = np.meshgrid(np.arange(image_width), np.arange(image_height))

    # Convert pixel coordinates to normalized device coordinates (NDC), from -1 to 1
    x_normalized = (x_idx - (image_width / 2)) / (image_width / 2)
    y_normalized = (y_idx - (image_height / 2)) / (image_height / 2)

    # Calculate spherical coordinates
    lambda_ = x_normalized * (h_fov / 2)
    phi_ = y_normalized * (v_fov / 2)

    # Convert spherical to Cartesian coordinates assuming unit sphere (radius = 1)
    x_cartesian = np.cos(phi_) * np.sin(lambda_)
    y_cartesian = np.sin(phi_)
    z_cartesian = np.cos(phi_) * np.cos(lambda_)

    # Stack to create Cartesian coordinate array for each pixel
    cartesian_coordinates = np.stack((x_cartesian, y_cartesian, z_cartesian), axis=-1)

    # Flatten the coordinate array to apply rotation
    cartesian_coordinates_flat = cartesian_coordinates.reshape(-1, 3)

    # Transform image to world coordinates
    camera_to_world = np.array([[0, 0, -1],
                               [1, 0, 0],
                                [0, 1, 0]])
    t = np.array([0, 0, 0.1])
    cartesian_coordinates_flat = np.dot(camera_to_world, cartesian_coordinates_flat.T).T + t

    # Create a rotation object from the rotation matrix
    rotation = R.from_matrix(rotation_matrix)

    # Apply rotation to the Cartesian coordinates
    world_coordinates_flat = rotation.apply(cartesian_coordinates_flat)

    # Reshape back to the original image shape with an additional dimension for the coordinates
    world_coordinates = world_coordinates_flat.reshape(image_height, image_width, 3)

    return world_coordinates

# get all world coordinates
world_coords_list = []
color_list = []
fov = (60, 45)
for i in range(0,len(image_list)):
    world_coords_list.append(image_to_world_coordinates(image_list[i], fov, closest_orientations[i]))
    color_list.append(image_list[i])
world_coords_list = np.array(world_coords_list)
color_list = np.array(color_list)
# view first 
print("world_coords_list shape: ", world_coords_list.shape)
print("color_list shape: ", color_list.shape)
# Out:
# world_coords_list shape:  (911, 240, 320, 3)
# color_list shape:  (911, 240, 320, 3)

# %%
import open3d as o3d
# visualize with color
pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(world_coords_list.reshape(-1, 3))
pcd.colors = o3d.utility.Vector3dVector(color_list.reshape(-1, 3) / 255)
o3d.visualization.draw_geometries([pcd])
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
def world_to_cylinder(world_coords):
    # Extract X, Y, Z coordinates
    X, Y, Z = world_coords[:, 0], world_coords[:, 1], world_coords[:, 2]
    # Calculate cylindrical coordinates
    width = np.arctan2(Y, X)  # Angular coordinate
    width = np.mod(width, 2 * np.pi)
    width = width / (2 * np.pi)

    height = Z / 2 + 0.5
    return width, height
world_coords_flat = world_coords_list.reshape(-1, 3)
color_flat = color_list.reshape(-1, 3)
x_2d, y_2d = world_to_cylinder(world_coords_flat)
# Project to 2D plane
x_res = 3000
y_res = 1000
x_2d = (x_2d * x_res).astype(int)
x_2d = np.clip(x_2d, 0, x_res - 1)
y_2d = (y_2d * y_res).astype(int)
y_2d = np.clip(y_2d, 0, y_res - 1)

# %%
cylinder_image = np.zeros((y_res, x_res, 3), dtype=np.uint8)
cylinder_image[y_2d, x_2d] = color_flat
plt.figure(figsize=(20, 10))
plt.imshow(cylinder_image)
